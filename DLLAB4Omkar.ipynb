# %% [markdown]
# <a href="https://colab.research.google.com/github/Annoymous-bot/DLL/blob/main/DLLAB4Omkar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tensorflow import keras
import tensorflow as tf
from sklearn.datasets import load_iris

# %%
dataset=load_iris()

# %%
a=pd.DataFrame(dataset['data'],columns=dataset['feature_names'])
a.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
a['feature_names']=dataset['target']
a.head()
# Out:
#    sepal length (cm)  sepal width (cm)  ...  petal width (cm)  feature_names
# 0                5.1               3.5  ...               0.2              0
# 1                4.9               3.0  ...               0.2              0
# 2                4.7               3.2  ...               0.2              0
# 3                4.6               3.1  ...               0.2              0
# 4                5.0               3.6  ...               0.2              0
#
# [5 rows x 5 columns]

# %%
from sklearn.model_selection import train_test_split
X=a.drop('feature_names',axis=1)
Y=a['feature_names']
xtrain,xtest,ytrain ,ytest  = train_test_split(X,Y,test_size=0.30,random_state=1)

# %%
xtest.head()
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 14                 5.8               4.0                1.2               0.2
# 98                 5.1               2.5                3.0               1.1
# 75                 6.6               3.0                4.4               1.4
# 16                 5.4               3.9                1.3               0.4
# 131                7.9               3.8                6.4               2.0

# %%
xtrain.shape
# Out:
# (105, 4)

# %%
ytrain.shape
# Out:
# (105,)

# %%
xtest.shape
# Out:
# (45, 4)

# %%
ytest.shape
# Out:
# (45,)

# %%
from keras.models import Sequential
from keras.layers import Dense

# %%
model=Sequential()
model.add(Dense(10,input_shape=(4,),activation='relu'))

# %%
                                                                                   #from keras.backend import spare_categorical_crossenyropy
model.compile(
    optimizer='adam',
    loss ='sparse_categorical_crossentropy',
    metrics=['accuracy']
)
model.fit(xtrain,ytrain,epochs=200)
# Out:
# Epoch 1/200
# 4/4 [==============================] - 0s 4ms/step - loss: 7.0455 - accuracy: 0.0000e+00
# Epoch 2/200
# 4/4 [==============================] - 0s 5ms/step - loss: 7.0454 - accuracy: 0.0000e+00
# Epoch 3/200
# 4/4 [==============================] - 0s 6ms/step - loss: 7.0452 - accuracy: 0.0000e+00
# Epoch 4/200
# 4/4 [==============================] - 0s 5ms/step - loss: 7.0453 - accuracy: 0.0000e+00
# Epoch 5/200
# 4/4 [==============================] - 0s 5ms/step - loss: 7.0452 - accuracy: 0.0000e+00
# Epoch 6/200
# 4/4 [==============================] - 0s 4ms/step - loss: 7.0451 - accuracy: 0.0000e+00
# Epoch 7/200
# 4/4 [==============================] - 0s 4ms/step - loss: 7.0451 - accuracy: 0.0000e+00
# Epoch 8/200
# 4/4 [==============================] - 0s 4ms/step - loss: 7.0451 - accuracy: 0.0000e+00
# Epoch 9/200
# 4/4 [==============================] - 0s 4ms/step - loss: 7.0452 - accuracy: 0.0000e+00
# Epoch 10/200
# ...
